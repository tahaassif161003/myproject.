# %%
import pandas as pd

pd.set_option("display.max_columns", None)   #this is used to show all the columns
df = pd.read_csv(r"c:\Users\Win\Desktop\New folder\movies.csv") 
df.sample(5) #it collects 5 random columns
# Out:
#                                               MOVIES               YEAR  \
# 3455                                       Intrusion        (II) (2021)
# 5200                           Heaven's Wedding Gown        (2004–2005)
# 5972                    Adel Karam: Live from Beirut  (2018 TV Special)
# 3959  Cateva conversatii despre o fata foarte inalta             (2018)
# 8886                               Memorias de Idhún        (2020–2021)
#
#                                            GENRE  RATING  \
# 3455                      \nThriller                 NaN
# 5200                         \nDrama                 6.2
# 5972                        \nComedy                 5.4
# 3959                         \nDrama                 5.9
# 8886  \nAnimation, Action, Adventure                 7.1
#
#                                                ONE-LINE  \
# 3455  \nA woman moves to a small town with her husba...
# 5200  \nIt was with much difficulty that Ai-Ching (C...
# ...

# %%
df.head(2) # by default it is 5
# Out:
#                                 MOVIES      YEAR  \
# 0                        Blood Red Sky    (2021)
# 1  Masters of the Universe: Revelation  (2021– )
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
#
#                                                STARS   VOTES  RunTime Gross
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...  21,062    121.0   NaN
# 1  \n            \n    Stars:\nChris Wood, \nSara...  17,870     25.0   NaN

# %%
df.tail(2) # the last 2 columns
# Out:
#                MOVIES      YEAR                                    GENRE  \
# 9997   The Imperfects  (2021– )  \nAdventure, Drama, Fantasy
# 9998   The Imperfects  (2021– )  \nAdventure, Drama, Fantasy
#
#       RATING        ONE-LINE  \
# 9997     NaN  \nAdd a Plot\n
# 9998     NaN  \nAdd a Plot\n
#
#                                                   STARS VOTES  RunTime Gross
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...   NaN      NaN   NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...   NaN      NaN   NaN

# %%
df.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross'],
#       dtype='object')

# %%
df.shape
# Out:
# (9999, 9)

# %%
df.describe() # humai aik numerical summary deti ha
# Out:
#             RATING      RunTime
# count  8179.000000  7041.000000
# mean      6.921176    68.688539
# std       1.220232    47.258056
# min       1.100000     1.000000
# 25%       6.200000    36.000000
# 50%       7.100000    60.000000
# 75%       7.800000    95.000000
# max       9.900000   853.000000

# %%
df.info() # to get the summary of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
df.isnull().sum()/df.shape[0]*100  # Divides the number of missing values in each column by the total number of rows
# Out:
# MOVIES       0.000000
# YEAR         6.440644
# GENRE        0.800080
# RATING      18.201820
# ONE-LINE     0.000000
# STARS        0.000000
# VOTES       18.201820
# RunTime     29.582958
# Gross       95.399540
# dtype: float64

# %%
df.drop(columns="Gross",inplace= True)   # drops thr column which we dont need

# %%
df.sample(3)
# Out:
#                                        MOVIES    YEAR  \
# 5402                           Student Driver     NaN
# 8470   Tiger King: Murder, Mayhem and Madness  (2020)
# 1349                               Desperados  (2020)
#
#                                             GENRE  RATING  \
# 5402                 \nAction, Comedy                 NaN
# 8470  \nDocumentary, Biography, Crime                 7.8
# 1349                \nComedy, Romance                 5.2
#
#                                                ONE-LINE  \
# 5402  \nA substitute driver's education teacher and ...
# 8470  \nAs Joe dives into politics, he deals with tu...
# 1349  \nA panicked young woman, with her reluctant f...
#
#                                                   STARS  VOTES  RunTime
# 5402                  \n    Director:\nKyle Newacheck\n    NaN      NaN
# 8470  \n    Directors:\nRebecca Chaiklin, \nEric Goo...  1,856     44.0
# ...

# %%
df.duplicated()   #checks for the duplicates if the rows are same it return as true and if not it returns as false
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9994     True
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# Length: 9999, dtype: bool

# %%
df1 = df.drop_duplicates()  # used to drop the duplicates

# %%
df1.duplicated().sum()  # adds up the true values
# Out:
# 0

# %%
df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9993    False
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# Length: 9568, dtype: bool

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# MOVIES      0
# YEAR        0
# GENRE       0
# RATING      0
# ONE-LINE    0
# STARS       0
# VOTES       0
# RunTime     0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# MOVIES      0
# YEAR        0
# GENRE       0
# RATING      0
# ONE-LINE    0
# STARS       0
# VOTES       0
# RunTime     0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6779 entries, 0 to 9963
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    6779 non-null   object
#  1   YEAR      6779 non-null   object
#  2   GENRE     6779 non-null   object
#  3   RATING    6779 non-null   float64
#  4   ONE-LINE  6779 non-null   object
#  5   STARS     6779 non-null   object
#  6   VOTES     6779 non-null   object
#  7   RunTime   6779 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 476.6+ KB

# %%
df["GENRE"].str.lstrip("\n")
# Out:
# 0           Action, Horror, Thriller
# 1       Animation, Action, Adventure
# 2            Drama, Horror, Thriller
# 3       Animation, Adventure, Comedy
# 4              Action, Crime, Horror
#                           ...
# 9994       Adventure, Drama, Fantasy
# 9995    Animation, Action, Adventure
# 9996              Documentary, Sport
# 9997       Adventure, Drama, Fantasy
# 9998       Adventure, Drama, Fantasy
# Name: GENRE, Length: 9999, dtype: object

# %%
df = df["GENRE"].str.lstrip("\n")
df
# Out:
# 0           Action, Horror, Thriller
# 1       Animation, Action, Adventure
# 2            Drama, Horror, Thriller
# 3       Animation, Adventure, Comedy
# 4              Action, Crime, Horror
#                           ...
# 9994       Adventure, Drama, Fantasy
# 9995    Animation, Action, Adventure
# 9996              Documentary, Sport
# 9997       Adventure, Drama, Fantasy
# 9998       Adventure, Drama, Fantasy
# Name: GENRE, Length: 9999, dtype: object

# %%
df1.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime'],
#       dtype='object')

# %%
group_1 = df1.groupby(["MOVIES", "YEAR"]).size()  #groups your DataFrame df1 by two columns: MOVIES and YEAR, and then counts the number of rows in each group.
#roups your DataFrame df1 by two columns: MOVIES and YEAR, and then counts the number of rows in each group.

# %%
df1["MOVIES"].value_counts().plot(kind = "bar", title = "overall rankings", color = "gray")
# Out:
# <Axes: title={'center': 'overall rankings'}, xlabel='MOVIES'>

# %%
df1["RunTime"].value_counts().plot(kind = "bar", title = "movies runtime", color = "gray")
# Out:
# <Axes: title={'center': 'movies runtime'}, xlabel='RunTime'>

# %%
df1["GENRE"].value_counts().plot(kind = "bar", title = "movies ", color = "gray")
# Out:
# <Axes: title={'center': 'movies '}, xlabel='GENRE'>
